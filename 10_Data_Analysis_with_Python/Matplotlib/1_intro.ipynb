# %% [markdown]
# ### Data  Visualization Wiht Matplotlib
# Metplotlib is a powerfull plotting library for python  that enables the creation  of static, animatedd, and  interactive visualization. It is widely used for data  visualization in data science and analytics.

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [1,4,9,16,25]

# %%
##create  aline plot
plt.plot(x,y)
plt.xlabel('X axis')
plt.ylabel('Y Axis')
plt.title("Basic line Plot")

plt.show()

# %%
x = [1,2,3,4,5,6]
y = [1,3,5,7,9,11]

## create customized line plot
plt.plot(x,y,color='red', linestyle='--')

# %%
plt.plot(x,y,color='red', linestyle='--',  marker='o')

# %%
plt.plot(x,y,color='red', linestyle='--', marker='o', linewidth=2)

# %%
plt.plot(x,y,color='red', linestyle='--', marker='o', linewidth=2, markersize=9)
plt.grid = True

# %%
##Mutiple  Plots
##  sample data
x = [1,2,3,4,5]
y1 = [1,3,5,7,9]
y2 = [2,4,6,8,10]


plt.Figure(figsize=(9,5))
plt.Subplot(1,2,1)
plt.plot(x,y1,color='green')

plt.title("Plot-1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 9
#       5 y2 = [2,4,6,8,10]
#       8 plt.Figure(figsize=(9,5))
# ----> 9 plt.Subplot(1,2,1)
#      10 plt.plot(x,y1,color='green')
#      12 plt.title("Plot-1")
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\matplotlib\axes\_base.py:692, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     690 else:
#     691     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 692     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     693 if self._position.width < 0 or self._position.height < 0:
#     694     raise ValueError('Width and height specified must be non-negative')
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\matplotlib\gridspec.py:576, in SubplotSpec._from_subplot_args(figure, args)
#     574     rows, cols, num = args
#     575 else:
# --> 576     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     578 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     579 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given
