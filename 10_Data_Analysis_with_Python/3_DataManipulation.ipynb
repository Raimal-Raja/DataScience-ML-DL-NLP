# %% [markdown]
# ### Data Manipulation and Analysis With pandas
# Data manipulation and analysis are key tasks in any data science or data analysis project. Pandas provides a wide range of functions for data manipulation and analysis, making it easier to clean, transform, and extract insights from data.

# %%
import pandas as pd

df = pd.read_csv('annual-enterprise.csv')

## fatch first 5 rows
df.head(5)
# Out:
#    Year Code                               Name Size-gap  \
# 0  2011    A  Agriculture, Forestry and Fishing      a_0
# 1  2011    A  Agriculture, Forestry and Fishing      a_0
# 2  2011    A  Agriculture, Forestry and Fishing      a_0
# 3  2011    A                                NaN      a_0
# 4  2011    A  Agriculture, Forestry and Fishing      a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
## fetch top bottom 5 rows
df.tail(5)
# Out:
#        Year Code            Name       Size-gap                     variable  \
# 20119  2023  all  All Industries  j_Grand_Total                 Total income
# 20120  2023  all  All Industries  j_Grand_Total            Total expenditure
# 20121  2023  all  All Industries  j_Grand_Total  Operating profit before tax
# 20122  2023  all  All Industries  j_Grand_Total                 Total assets
# 20123  2023  all  All Industries  j_Grand_Total        Fixed tangible assets
#
#          value               unit
# 20119   930995  DOLLARS(millions)
# 20120   832964  DOLLARS(millions)
# 20121   103616  DOLLARS(millions)
# 20122  2831894  DOLLARS(millions)
# 20123   681890  DOLLARS(millions)

# %%
df.describe()
# Out:
#               Year
# count  20124.00000
# mean    2017.00000
# std        3.74175
# min     2011.00000
# 25%     2014.00000
# 50%     2017.00000
# 75%     2020.00000
# max     2023.00000

# %%
df.dtypes
# Out:
# Year         int64
# Code        object
# Name        object
# Size-gap    object
# variable    object
# value       object
# unit        object
# dtype: object

# %% [markdown]
# ### Handling missing values

# %%
## handling missing values
# df.isnull().any(axis=1)
df.isnull().sum()
# Out:
# Year        0
# Code        0
# Name        1
# Size-gap    3
# variable    0
# value       2
# unit        0
# dtype: int64

# %%
# file empy values with 0
df.fillna('N/A')
# Out:
#        Year Code                               Name       Size-gap  \
# 0      2011    A  Agriculture, Forestry and Fishing            a_0
# 1      2011    A  Agriculture, Forestry and Fishing            a_0
# 2      2011    A  Agriculture, Forestry and Fishing            a_0
# 3      2011    A                                N/A            a_0
# 4      2011    A  Agriculture, Forestry and Fishing            a_0
# ...     ...  ...                                ...            ...
# 20119  2023  all                     All Industries  j_Grand_Total
# 20120  2023  all                     All Industries  j_Grand_Total
# 20121  2023  all                     All Industries  j_Grand_Total
# 20122  2023  all                     All Industries  j_Grand_Total
# 20123  2023  all                     All Industries  j_Grand_Total
#
#                                               variable    value  \
# 0                                        Activity unit    46134
# 1                               Rolling mean employees        0
# 2                              Salaries and wages paid      279
# 3      Sales, government funding, grants and subsidies     8187
# 4                                         Total income     8866
# ...                                                ...      ...
# 20119                                     Total income   930995
# 20120                                Total expenditure   832964
# 20121                      Operating profit before tax   103616
# 20122                                     Total assets  2831894
# 20123                            Fixed tangible assets   681890
#
#                     unit
# 0                  COUNT
# 1                  COUNT
# 2      DOLLARS(millions)
# 3      DOLLARS(millions)
# 4      DOLLARS(millions)
# ...                  ...
# 20119  DOLLARS(millions)
# 20120  DOLLARS(millions)
# 20121  DOLLARS(millions)
# 20122  DOLLARS(millions)
# 20123  DOLLARS(millions)
#
# [20124 rows x 7 columns]

# %%
### filling missing values with the mean of the column
df['missing_values'] = df['value'].fillna(df['value'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 ### filling missing values with the mean of the column
# ----> 2 df['missing_values'] = df['value'].fillna(df['value'].mean())
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)  12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
#   12440         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12441     )
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\series.py:6468, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6463     # GH#47500 - change to TypeError to match other methods
#    6464     raise TypeError(
#    6465         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6466         "with non-numeric dtypes."
#    6467     )
# -> 6468 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\Professor\Desktop\Programming\DataScience-ML-DL-NLP-Projects&Practice\.venv\Lib\site-packages\numpy\_core\_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
## Renaming Columns
df = df.rename(columns={'Code':'Item_code'})

# %%
df.head()
# Out:
#    Year Item_code                               Name Size-gap  \
# 0  2011         A  Agriculture, Forestry and Fishing      a_0
# 1  2011         A  Agriculture, Forestry and Fishing      a_0
# 2  2011         A  Agriculture, Forestry and Fishing      a_0
# 3  2011         A                                NaN      a_0
# 4  2011         A  Agriculture, Forestry and Fishing      a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
## Change DataType
df['NewCode'] = df['Year'].astype(float)

# %%
df
# Out:
#        Year Item_code                               Name       Size-gap  \
# 0      2011         A  Agriculture, Forestry and Fishing            a_0
# 1      2011         A  Agriculture, Forestry and Fishing            a_0
# 2      2011         A  Agriculture, Forestry and Fishing            a_0
# 3      2011         A                                NaN            a_0
# 4      2011         A  Agriculture, Forestry and Fishing            a_0
# ...     ...       ...                                ...            ...
# 20119  2023       all                     All Industries  j_Grand_Total
# 20120  2023       all                     All Industries  j_Grand_Total
# 20121  2023       all                     All Industries  j_Grand_Total
# 20122  2023       all                     All Industries  j_Grand_Total
# 20123  2023       all                     All Industries  j_Grand_Total
#
#                                               variable    value  \
# 0                                        Activity unit    46134
# 1                               Rolling mean employees        0
# 2                              Salaries and wages paid      279
# 3      Sales, government funding, grants and subsidies     8187
# 4                                         Total income     8866
# ...                                                ...      ...
# 20119                                     Total income   930995
# 20120                                Total expenditure   832964
# 20121                      Operating profit before tax   103616
# 20122                                     Total assets  2831894
# 20123                            Fixed tangible assets   681890
#
#                     unit  NewCode
# 0                  COUNT   2011.0
# 1                  COUNT   2011.0
# 2      DOLLARS(millions)   2011.0
# 3      DOLLARS(millions)   2011.0
# 4      DOLLARS(millions)   2011.0
# ...                  ...      ...
# 20119  DOLLARS(millions)   2023.0
# 20120  DOLLARS(millions)   2023.0
# 20121  DOLLARS(millions)   2023.0
# 20122  DOLLARS(millions)   2023.0
# 20123  DOLLARS(millions)   2023.0
#
# [20124 rows x 8 columns]

# %%
df['new_value'] = df["Year"].fillna(df['NewCode'].mean()).astype(int)

# %%
df
# Out:
#        Year Item_code                               Name       Size-gap  \
# 0      2011         A  Agriculture, Forestry and Fishing            a_0
# 1      2011         A  Agriculture, Forestry and Fishing            a_0
# 2      2011         A  Agriculture, Forestry and Fishing            a_0
# 3      2011         A                                NaN            a_0
# 4      2011         A  Agriculture, Forestry and Fishing            a_0
# ...     ...       ...                                ...            ...
# 20119  2023       all                     All Industries  j_Grand_Total
# 20120  2023       all                     All Industries  j_Grand_Total
# 20121  2023       all                     All Industries  j_Grand_Total
# 20122  2023       all                     All Industries  j_Grand_Total
# 20123  2023       all                     All Industries  j_Grand_Total
#
#                                               variable    value  \
# 0                                        Activity unit    46134
# 1                               Rolling mean employees        0
# 2                              Salaries and wages paid      279
# 3      Sales, government funding, grants and subsidies     8187
# 4                                         Total income     8866
# ...                                                ...      ...
# 20119                                     Total income   930995
# 20120                                Total expenditure   832964
# 20121                      Operating profit before tax   103616
# 20122                                     Total assets  2831894
# 20123                            Fixed tangible assets   681890
#
#                     unit  NewCode  new_value
# 0                  COUNT   2011.0       2011
# 1                  COUNT   2011.0       2011
# 2      DOLLARS(millions)   2011.0       2011
# 3      DOLLARS(millions)   2011.0       2011
# 4      DOLLARS(millions)   2011.0       2011
# ...                  ...      ...        ...
# 20119  DOLLARS(millions)   2023.0       2023
# 20120  DOLLARS(millions)   2023.0       2023
# 20121  DOLLARS(millions)   2023.0       2023
# 20122  DOLLARS(millions)   2023.0       2023
# 20123  DOLLARS(millions)   2023.0       2023
#
# [20124 rows x 9 columns]
