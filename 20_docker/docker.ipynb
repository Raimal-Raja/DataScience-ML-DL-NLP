# %% [markdown]
# ## container
# A way to package application with all the necessary dependencies and configuration
#
# Portable oritifact, easily share and more this package to any environment
#
# make developement and deployement move easy and efficient

# %% [markdown]
# ## Basic Commands

# %% [markdown]
#  1 - Docker Pull Command
# * ``` docker pull docker/getting-started ```
#
#  2 - Check Docker version
# * ``` docker -v ```
#
#  3 - Run Docker image (-d = deteched mode, -p = assigning port 90:90 (first 90 for host port and second 90 for container port))
# * ``` docker run -d -p 80:80 (image name here) ```
# * ``` docker run -d -p 80:80 docker/getting-started ```
#
#  4 - Checking downloaded images
# * ``` docker images ```
#
#  5 - Checking running containers
# * ``` docker ps ```
#
# 6 - Stop container
# * ``` docker stop (container id here) ```
#
# 7 - Remove docker image
# * ``` docker rm (image id here) ```
#
# 8 - Remove docker image forcefully
# * ``` docker rm -f (image id here) ```
#
# 9 - Run without pulling (it will pull if not exist and then  run it)
# * ` docker run hello-world `

# %% [markdown]
# ## Create docker image commands

# %% [markdown]
# - FROM (python : version alpine)
# - COPY (to the folder where project will be containerized on docker hub) (source and distination)
# - WORKDIR (dir where you have create container)
# - RUN (install requirements using pip)
# - CMD (run project main file)

# %% [markdown]
# ## Docker Image Build Commands

# %% [markdown]
# * docker build -t (give name to app) (dir/path)
# eg; docker build -t welcome-app .
